# %% [markdown]
# - Agrega offset de 0.5 y duration reducida a 2.5 respecto a v1 (Resultado: Mejora de accuracy de 5%)
# - Agregar 5 bines (Resultado: Caída de accuracy de 10%)
# - Intentar notebook https://www.kaggle.com/code/lkergalipatak/speech-emotion-recognition-with-cnn/notebook

# %% [markdown]
# ## Imports

# %%
import os
import sys

# Set parent directory
os.chdir(os.path.dirname(os.getcwd()))

import pandas as pd
import numpy as np

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
#import librosa.display # Aparentemente esto bugea todo segun un git issue 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import keras
from python_speech_features import mfcc
import scipy.io.wavfile as wav
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
# from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

from joblib import dump, load

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Data load

# %%
base_url = "C:/Users/Emanuel/Documents/Github/SER/datasets"

# Paths for data.
Ravdess = f"{base_url}/RAVDESS/audio_speech_actors_01-24"

ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + f'/{dir}')
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + f'/{dir}/{file}')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 1  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 2  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 3  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 4     calm  C:/Users/Emanuel/Documents/Github/SER/datasets...

# %% [markdown]
# ## Feature Extraction

# %%
X, Y = [], []

for path, emotion in zip(Ravdess_df.Path, Ravdess_df.Emotions):
    
    data, sample_rate = librosa.load(path, duration = 2.5, offset = 0.5)
    
    X.append(np.mean(librosa.feature.mfcc(y = data, sr = sample_rate, n_mfcc = 13),axis = 0))
    Y.append(emotion)
    
df_features = pd.DataFrame(X)

df_features['labels'] = Y

# %% [markdown]
# ## Data preparation

# %%
df_features.fillna(0, inplace = True)

# %%
X = df_features.iloc[: ,:-1].values
Y = df_features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 108), (1080, 8), (360, 108), (360, 8))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 108), (1080, 8), (360, 108), (360, 8))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 108, 1), (1080, 8), (360, 108, 1), (360, 8))

# %% [markdown]
# ## Model Training

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 108, 256)          1536
#
#  max_pooling1d_4 (MaxPoolin  (None, 54, 256)           0
#  g1D)
#
#  conv1d_5 (Conv1D)           (None, 54, 256)           327936
#
#  max_pooling1d_5 (MaxPoolin  (None, 27, 256)           0
#  g1D)
#
#  conv1d_6 (Conv1D)           (None, 27, 128)           163968
#
#  max_pooling1d_6 (MaxPoolin  (None, 14, 128)           0
#  g1D)
#
#  dropout_2 (Dropout)         (None, 14, 128)           0
#
#  conv1d_7 (Conv1D)           (None, 14, 64)            41024
#
#  max_pooling1d_7 (MaxPoolin  (None, 7, 64)             0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 448)               0
#
#  dense_2 (Dense)             (None, 32)                14368
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 549096 (2.09 MB)
# Trainable params: 549096 (2.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 47ms/step - loss: 2.0435 - accuracy: 0.1926 - val_loss: 1.9689 - val_accuracy: 0.2222 - lr: 0.0010
# Epoch 2/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.9847 - accuracy: 0.2176 - val_loss: 1.9359 - val_accuracy: 0.2778 - lr: 0.0010
# Epoch 3/100
# 17/17 [==============================] - 1s 40ms/step - loss: 1.9322 - accuracy: 0.2435 - val_loss: 1.9329 - val_accuracy: 0.2889 - lr: 0.0010
# Epoch 4/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.9012 - accuracy: 0.2537 - val_loss: 1.8574 - val_accuracy: 0.2944 - lr: 0.0010
# Epoch 5/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.8788 - accuracy: 0.2694 - val_loss: 1.8537 - val_accuracy: 0.3194 - lr: 0.0010
# Epoch 6/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.8709 - accuracy: 0.2713 - val_loss: 1.8224 - val_accuracy: 0.3222 - lr: 0.0010
# Epoch 7/100
# 17/17 [==============================] - 1s 41ms/step - loss: 1.8364 - accuracy: 0.2843 - val_loss: 1.8121 - val_accuracy: 0.3417 - lr: 0.0010
# Epoch 8/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.8165 - accuracy: 0.2926 - val_loss: 1.7798 - val_accuracy: 0.3194 - lr: 0.0010
# Epoch 9/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.7982 - accuracy: 0.2935 - val_loss: 1.7744 - val_accuracy: 0.3500 - lr: 0.0010
# Epoch 10/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.7887 - accuracy: 0.2981 - val_loss: 1.7711 - val_accuracy: 0.3500 - lr: 0.0010
# Epoch 11/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.7552 - accuracy: 0.3139 - val_loss: 1.7235 - val_accuracy: 0.3778 - lr: 0.0010
# Epoch 12/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.7574 - accuracy: 0.3111 - val_loss: 1.7528 - val_accuracy: 0.3444 - lr: 0.0010
# Epoch 13/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6848 - accuracy: 0.3639 - val_loss: 1.7005 - val_accuracy: 0.3611 - lr: 0.0010
# Epoch 14/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6762 - accuracy: 0.3426 - val_loss: 1.6772 - val_accuracy: 0.3944 - lr: 0.0010
# Epoch 15/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6714 - accuracy: 0.3574 - val_loss: 1.6623 - val_accuracy: 0.3889 - lr: 0.0010
# Epoch 16/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.6525 - accuracy: 0.3593 - val_loss: 1.6672 - val_accuracy: 0.3861 - lr: 0.0010
# Epoch 17/100
# 17/17 [==============================] - 1s 42ms/step - loss: 1.6185 - accuracy: 0.3796 - val_loss: 1.6436 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 18/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.6030 - accuracy: 0.3889 - val_loss: 1.5958 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 19/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.5650 - accuracy: 0.3787 - val_loss: 1.5973 - val_accuracy: 0.4111 - lr: 0.0010
# Epoch 20/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.5488 - accuracy: 0.4102 - val_loss: 1.6060 - val_accuracy: 0.4028 - lr: 0.0010
# Epoch 21/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.5057 - accuracy: 0.4389 - val_loss: 1.6255 - val_accuracy: 0.3722 - lr: 0.0010
# Epoch 22/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.4756 - accuracy: 0.4370 - val_loss: 1.5251 - val_accuracy: 0.4500 - lr: 0.0010
# Epoch 23/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.4546 - accuracy: 0.4454 - val_loss: 1.5600 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 24/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.4158 - accuracy: 0.4398 - val_loss: 1.5412 - val_accuracy: 0.4389 - lr: 0.0010
# Epoch 25/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.3849 - accuracy: 0.4611 - val_loss: 1.5186 - val_accuracy: 0.4444 - lr: 0.0010
# Epoch 26/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.3655 - accuracy: 0.4583 - val_loss: 1.5392 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 27/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.3382 - accuracy: 0.4889 - val_loss: 1.5548 - val_accuracy: 0.4250 - lr: 0.0010
# Epoch 28/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.3066 - accuracy: 0.4935 - val_loss: 1.5563 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 29/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.3058 - accuracy: 0.4935 - val_loss: 1.5406 - val_accuracy: 0.4472 - lr: 0.0010
# Epoch 30/100
# 17/17 [==============================] - 1s 46ms/step - loss: 1.2515 - accuracy: 0.5185 - val_loss: 1.5655 - val_accuracy: 0.4472 - lr: 0.0010
# Epoch 31/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.1854 - accuracy: 0.5593 - val_loss: 1.5159 - val_accuracy: 0.4750 - lr: 0.0010
# Epoch 32/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.1920 - accuracy: 0.5556 - val_loss: 1.5310 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 33/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.0959 - accuracy: 0.5731 - val_loss: 1.5453 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 34/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.1065 - accuracy: 0.5694 - val_loss: 1.5379 - val_accuracy: 0.4361 - lr: 0.0010
# Epoch 35/100
# 17/17 [==============================] - 1s 45ms/step - loss: 1.0670 - accuracy: 0.5917 - val_loss: 1.5546 - val_accuracy: 0.4722 - lr: 0.0010
# Epoch 36/100
# 17/17 [==============================] - 1s 44ms/step - loss: 1.0238 - accuracy: 0.6074 - val_loss: 1.6320 - val_accuracy: 0.4694 - lr: 0.0010
# Epoch 37/100
# 17/17 [==============================] - 1s 43ms/step - loss: 1.0492 - accuracy: 0.6065 - val_loss: 1.5986 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 38/100
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9958 - accuracy: 0.6324 - val_loss: 1.5986 - val_accuracy: 0.4639 - lr: 0.0010
# Epoch 39/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9309 - accuracy: 0.6556 - val_loss: 1.6201 - val_accuracy: 0.4778 - lr: 0.0010
# Epoch 40/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9285 - accuracy: 0.6370 - val_loss: 1.5549 - val_accuracy: 0.4806 - lr: 0.0010
# Epoch 41/100
# 17/17 [==============================] - 1s 45ms/step - loss: 0.8644 - accuracy: 0.6630 - val_loss: 1.6171 - val_accuracy: 0.4806 - lr: 0.0010
# Epoch 42/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9281 - accuracy: 0.6407 - val_loss: 1.5947 - val_accuracy: 0.4639 - lr: 0.0010
# Epoch 43/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9094 - accuracy: 0.6731 - val_loss: 1.6652 - val_accuracy: 0.4528 - lr: 0.0010
# Epoch 44/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.8046 - accuracy: 0.6944 - val_loss: 1.6211 - val_accuracy: 0.4778 - lr: 4.0000e-04
# Epoch 45/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.6787 - accuracy: 0.7454 - val_loss: 1.6843 - val_accuracy: 0.4750 - lr: 4.0000e-04
# Epoch 46/100
# 17/17 [==============================] - 1s 46ms/step - loss: 0.6582 - accuracy: 0.7491 - val_loss: 1.7665 - val_accuracy: 0.4583 - lr: 4.0000e-04
# Epoch 47/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.6388 - accuracy: 0.7759 - val_loss: 1.7012 - val_accuracy: 0.4750 - lr: 4.0000e-04
# Epoch 48/100
# 17/17 [==============================] - 1s 44ms/step - loss: 0.6432 - accuracy: 0.7676 - val_loss: 1.6912 - val_accuracy: 0.4639 - lr: 4.0000e-04
# Epoch 49/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6093 - accuracy: 0.7806 - val_loss: 1.6982 - val_accuracy: 0.4750 - lr: 4.0000e-04
# Epoch 50/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6400 - accuracy: 0.7676 - val_loss: 1.7888 - val_accuracy: 0.4861 - lr: 4.0000e-04
# Epoch 51/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5872 - accuracy: 0.7907 - val_loss: 1.7835 - val_accuracy: 0.4556 - lr: 4.0000e-04
# Epoch 52/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5983 - accuracy: 0.7713 - val_loss: 1.8292 - val_accuracy: 0.4722 - lr: 4.0000e-04
# Epoch 53/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5866 - accuracy: 0.7657 - val_loss: 1.7695 - val_accuracy: 0.4694 - lr: 4.0000e-04
# Epoch 54/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.5539 - accuracy: 0.7981 - val_loss: 1.7980 - val_accuracy: 0.4944 - lr: 4.0000e-04
# Epoch 55/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5621 - accuracy: 0.7926 - val_loss: 1.7920 - val_accuracy: 0.4639 - lr: 4.0000e-04
# Epoch 56/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5625 - accuracy: 0.8065 - val_loss: 1.8143 - val_accuracy: 0.4694 - lr: 4.0000e-04
# Epoch 57/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5293 - accuracy: 0.8074 - val_loss: 1.8351 - val_accuracy: 0.4861 - lr: 1.6000e-04
# Epoch 58/100
# 17/17 [==============================] - 1s 59ms/step - loss: 0.5090 - accuracy: 0.8102 - val_loss: 1.8501 - val_accuracy: 0.4722 - lr: 1.6000e-04
# Epoch 59/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4901 - accuracy: 0.8194 - val_loss: 1.8741 - val_accuracy: 0.4611 - lr: 1.6000e-04
# Epoch 60/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4784 - accuracy: 0.8176 - val_loss: 1.8869 - val_accuracy: 0.4583 - lr: 1.6000e-04
# Epoch 61/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4637 - accuracy: 0.8231 - val_loss: 1.8908 - val_accuracy: 0.4722 - lr: 1.6000e-04
# Epoch 62/100
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4930 - accuracy: 0.8176 - val_loss: 1.9217 - val_accuracy: 0.4639 - lr: 1.6000e-04
# Epoch 63/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4539 - accuracy: 0.8352 - val_loss: 1.9246 - val_accuracy: 0.4639 - lr: 1.6000e-04
# Epoch 64/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4727 - accuracy: 0.8306 - val_loss: 1.9155 - val_accuracy: 0.4583 - lr: 1.6000e-04
# Epoch 65/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4476 - accuracy: 0.8370 - val_loss: 1.9105 - val_accuracy: 0.4750 - lr: 1.6000e-04
# Epoch 66/100
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4627 - accuracy: 0.8389 - val_loss: 1.9310 - val_accuracy: 0.4778 - lr: 1.6000e-04
# Epoch 67/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4583 - accuracy: 0.8324 - val_loss: 1.9202 - val_accuracy: 0.4694 - lr: 1.6000e-04
# Epoch 68/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4152 - accuracy: 0.8528 - val_loss: 1.9318 - val_accuracy: 0.4639 - lr: 6.4000e-05
# Epoch 69/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4118 - accuracy: 0.8435 - val_loss: 1.9367 - val_accuracy: 0.4611 - lr: 6.4000e-05
# Epoch 70/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4337 - accuracy: 0.8537 - val_loss: 1.9243 - val_accuracy: 0.4778 - lr: 6.4000e-05
# Epoch 71/100
# 17/17 [==============================] - 1s 67ms/step - loss: 0.4251 - accuracy: 0.8435 - val_loss: 1.9391 - val_accuracy: 0.4667 - lr: 6.4000e-05
# Epoch 72/100
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4363 - accuracy: 0.8389 - val_loss: 1.9516 - val_accuracy: 0.4639 - lr: 2.5600e-05
# Epoch 73/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4244 - accuracy: 0.8426 - val_loss: 1.9591 - val_accuracy: 0.4639 - lr: 2.5600e-05
# Epoch 74/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4064 - accuracy: 0.8481 - val_loss: 1.9552 - val_accuracy: 0.4583 - lr: 1.0240e-05
# Epoch 75/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4007 - accuracy: 0.8537 - val_loss: 1.9565 - val_accuracy: 0.4556 - lr: 1.0240e-05
# Epoch 76/100
# 17/17 [==============================] - 1s 67ms/step - loss: 0.4592 - accuracy: 0.8222 - val_loss: 1.9570 - val_accuracy: 0.4583 - lr: 1.0240e-05
# Epoch 77/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4202 - accuracy: 0.8444 - val_loss: 1.9603 - val_accuracy: 0.4556 - lr: 1.0240e-05
# Epoch 78/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4095 - accuracy: 0.8602 - val_loss: 1.9607 - val_accuracy: 0.4556 - lr: 4.0960e-06
# Epoch 79/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.4324 - accuracy: 0.8315 - val_loss: 1.9606 - val_accuracy: 0.4556 - lr: 4.0960e-06
# Epoch 80/100
# 17/17 [==============================] - 1s 64ms/step - loss: 0.3907 - accuracy: 0.8639 - val_loss: 1.9603 - val_accuracy: 0.4556 - lr: 1.6384e-06
# Epoch 81/100
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4164 - accuracy: 0.8454 - val_loss: 1.9604 - val_accuracy: 0.4528 - lr: 1.6384e-06
# Epoch 82/100
# 17/17 [==============================] - 1s 70ms/step - loss: 0.4004 - accuracy: 0.8500 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.6384e-06
# Epoch 83/100
# 17/17 [==============================] - 1s 70ms/step - loss: 0.4271 - accuracy: 0.8361 - val_loss: 1.9613 - val_accuracy: 0.4528 - lr: 6.5536e-07
# Epoch 84/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4201 - accuracy: 0.8491 - val_loss: 1.9611 - val_accuracy: 0.4528 - lr: 6.5536e-07
# Epoch 85/100
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4029 - accuracy: 0.8565 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 2.6214e-07
# Epoch 86/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4090 - accuracy: 0.8491 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 2.6214e-07
# Epoch 87/100
# 17/17 [==============================] - 1s 72ms/step - loss: 0.4087 - accuracy: 0.8519 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0486e-07
# Epoch 88/100
# 17/17 [==============================] - 1s 73ms/step - loss: 0.4286 - accuracy: 0.8407 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0486e-07
# Epoch 89/100
# 17/17 [==============================] - 1s 73ms/step - loss: 0.4381 - accuracy: 0.8435 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 90/100
# 17/17 [==============================] - 1s 72ms/step - loss: 0.4253 - accuracy: 0.8426 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 91/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4118 - accuracy: 0.8565 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 92/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4457 - accuracy: 0.8380 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 93/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4379 - accuracy: 0.8306 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 94/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.4569 - accuracy: 0.8231 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 95/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.4318 - accuracy: 0.8380 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 96/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4225 - accuracy: 0.8509 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 97/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4354 - accuracy: 0.8389 - val_loss: 1.9610 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 98/100
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4380 - accuracy: 0.8463 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 99/100
# 17/17 [==============================] - 1s 63ms/step - loss: 0.4435 - accuracy: 0.8352 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07
# Epoch 100/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.4223 - accuracy: 0.8519 - val_loss: 1.9609 - val_accuracy: 0.4528 - lr: 1.0000e-07

# %% [markdown]
# ## Results

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9609 - accuracy: 0.4528
# Accuracy of our model on test data :  45.277777314186096 %

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 0s 7ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1            angry          fear
# 2         surprise      surprise
# 3            angry         angry
# 4             calm           sad
# 5              sad          calm
# 6          disgust          calm
# 7         surprise          fear
# 8          disgust       disgust
# 9          disgust       disgust

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.59      0.58      0.58        45
#         calm       0.53      0.39      0.45        54
#      disgust       0.56      0.52      0.54        46
#         fear       0.45      0.45      0.45        47
#        happy       0.24      0.31      0.27        42
#      neutral       0.45      0.46      0.46        28
#          sad       0.30      0.29      0.29        45
#     surprise       0.55      0.60      0.58        53
#
#     accuracy                           0.45       360
#    macro avg       0.46      0.45      0.45       360
# weighted avg       0.46      0.45      0.46       360
