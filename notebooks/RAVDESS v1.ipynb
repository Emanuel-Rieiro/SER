# %% [markdown]
# La idea es que sea una notebook simple, usando RAVDESS, MFCC y CNN

# %% [markdown]
# ## Imports

# %%
import os
import sys

# Set parent directory
os.chdir(os.path.dirname(os.getcwd()))

import pandas as pd
import numpy as np

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
#import librosa.display # Aparentemente esto bugea todo segun un git issue 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
# from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

from joblib import dump, load

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Data load

# %%
base_url = "C:/Users/Emanuel/Documents/Github/SER/datasets"

# Paths for data.
Ravdess = f"{base_url}/RAVDESS/audio_speech_actors_01-24"

ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + f'/{dir}')
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + f'/{dir}/{file}')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 1  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 2  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 3  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 4     calm  C:/Users/Emanuel/Documents/Github/SER/datasets...

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ## Data preparation

# %%
X = df_features.iloc[: ,:-1].values
Y = df_features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20), (1080, 8), (360, 20), (360, 8))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20), (1080, 8), (360, 20), (360, 8))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20, 1), (1080, 8), (360, 20, 1), (360, 8))

# %% [markdown]
# ## Model Training

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 256)           1536
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           327936
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            163968
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 128)            0
#  g1D)
#
#  dropout (Dropout)           (None, 3, 128)            0
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             41024
#
#  max_pooling1d_3 (MaxPoolin  (None, 2, 64)             0
#  g1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 538856 (2.06 MB)
# Trainable params: 538856 (2.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 22ms/step - loss: 2.0713 - accuracy: 0.1454 - val_loss: 2.0322 - val_accuracy: 0.1639 - lr: 0.0010
# Epoch 2/100
# 17/17 [==============================] - 0s 13ms/step - loss: 2.0369 - accuracy: 0.1509 - val_loss: 1.9935 - val_accuracy: 0.1972 - lr: 0.0010
# Epoch 3/100
# 17/17 [==============================] - 0s 14ms/step - loss: 2.0106 - accuracy: 0.1972 - val_loss: 1.9725 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9810 - accuracy: 0.2148 - val_loss: 1.9523 - val_accuracy: 0.2194 - lr: 0.0010
# Epoch 5/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.9641 - accuracy: 0.2167 - val_loss: 1.9267 - val_accuracy: 0.2417 - lr: 0.0010
# Epoch 6/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9273 - accuracy: 0.2352 - val_loss: 1.9188 - val_accuracy: 0.2417 - lr: 0.0010
# Epoch 7/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.9270 - accuracy: 0.2287 - val_loss: 1.8921 - val_accuracy: 0.2361 - lr: 0.0010
# Epoch 8/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.8579 - accuracy: 0.2657 - val_loss: 1.8370 - val_accuracy: 0.2917 - lr: 0.0010
# Epoch 9/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.8287 - accuracy: 0.2769 - val_loss: 1.7931 - val_accuracy: 0.3278 - lr: 0.0010
# Epoch 10/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.7491 - accuracy: 0.3222 - val_loss: 1.6985 - val_accuracy: 0.3611 - lr: 0.0010
# Epoch 11/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.7319 - accuracy: 0.3130 - val_loss: 1.7085 - val_accuracy: 0.3833 - lr: 0.0010
# Epoch 12/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.6846 - accuracy: 0.3454 - val_loss: 1.6565 - val_accuracy: 0.3778 - lr: 0.0010
# Epoch 13/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.6058 - accuracy: 0.3852 - val_loss: 1.5859 - val_accuracy: 0.3889 - lr: 0.0010
# Epoch 14/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.5238 - accuracy: 0.4167 - val_loss: 1.5611 - val_accuracy: 0.3889 - lr: 0.0010
# Epoch 15/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.4827 - accuracy: 0.4593 - val_loss: 1.5478 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 16/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.4692 - accuracy: 0.4556 - val_loss: 1.5487 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 17/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.4174 - accuracy: 0.4907 - val_loss: 1.4918 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 18/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.3667 - accuracy: 0.4907 - val_loss: 1.4950 - val_accuracy: 0.4528 - lr: 0.0010
# Epoch 19/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.3084 - accuracy: 0.5130 - val_loss: 1.4640 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 20/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.2529 - accuracy: 0.5509 - val_loss: 1.3831 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 21/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.1509 - accuracy: 0.5759 - val_loss: 1.3856 - val_accuracy: 0.4972 - lr: 0.0010
# Epoch 22/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.1194 - accuracy: 0.5796 - val_loss: 1.4293 - val_accuracy: 0.4694 - lr: 0.0010
# Epoch 23/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.0456 - accuracy: 0.6074 - val_loss: 1.4026 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 24/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.0223 - accuracy: 0.6287 - val_loss: 1.4394 - val_accuracy: 0.4917 - lr: 0.0010
# Epoch 25/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.9951 - accuracy: 0.6315 - val_loss: 1.3276 - val_accuracy: 0.5083 - lr: 0.0010
# Epoch 26/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9021 - accuracy: 0.6731 - val_loss: 1.5385 - val_accuracy: 0.4722 - lr: 0.0010
# Epoch 27/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9318 - accuracy: 0.6694 - val_loss: 1.3682 - val_accuracy: 0.5194 - lr: 0.0010
# Epoch 28/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.8531 - accuracy: 0.6898 - val_loss: 1.3544 - val_accuracy: 0.5194 - lr: 0.0010
# Epoch 29/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.7979 - accuracy: 0.7185 - val_loss: 1.6011 - val_accuracy: 0.4861 - lr: 0.0010
# Epoch 30/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.7314 - accuracy: 0.7481 - val_loss: 1.3263 - val_accuracy: 0.5583 - lr: 0.0010
# Epoch 31/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.7272 - accuracy: 0.7509 - val_loss: 1.3020 - val_accuracy: 0.5611 - lr: 0.0010
# Epoch 32/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6743 - accuracy: 0.7583 - val_loss: 1.3724 - val_accuracy: 0.5361 - lr: 0.0010
# Epoch 33/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6059 - accuracy: 0.7852 - val_loss: 1.4624 - val_accuracy: 0.5139 - lr: 0.0010
# Epoch 34/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5785 - accuracy: 0.7981 - val_loss: 1.3232 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 35/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4482 - accuracy: 0.8509 - val_loss: 1.5415 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 36/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4710 - accuracy: 0.8380 - val_loss: 1.6311 - val_accuracy: 0.5361 - lr: 0.0010
# Epoch 37/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4403 - accuracy: 0.8454 - val_loss: 1.5896 - val_accuracy: 0.5250 - lr: 0.0010
# Epoch 38/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3717 - accuracy: 0.8676 - val_loss: 1.5086 - val_accuracy: 0.5722 - lr: 0.0010
# Epoch 39/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3298 - accuracy: 0.8981 - val_loss: 1.6440 - val_accuracy: 0.5472 - lr: 0.0010
# Epoch 40/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3356 - accuracy: 0.8889 - val_loss: 1.6254 - val_accuracy: 0.5583 - lr: 0.0010
# Epoch 41/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2759 - accuracy: 0.9139 - val_loss: 1.7196 - val_accuracy: 0.5472 - lr: 0.0010
# Epoch 42/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3016 - accuracy: 0.9037 - val_loss: 1.8986 - val_accuracy: 0.5389 - lr: 0.0010
# Epoch 43/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3725 - accuracy: 0.8722 - val_loss: 1.7084 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 44/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2183 - accuracy: 0.9380 - val_loss: 1.7831 - val_accuracy: 0.5667 - lr: 4.0000e-04
# Epoch 45/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1656 - accuracy: 0.9546 - val_loss: 1.6553 - val_accuracy: 0.5972 - lr: 4.0000e-04
# Epoch 46/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1445 - accuracy: 0.9611 - val_loss: 1.8154 - val_accuracy: 0.5806 - lr: 4.0000e-04
# Epoch 47/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1408 - accuracy: 0.9593 - val_loss: 1.8092 - val_accuracy: 0.5944 - lr: 4.0000e-04
# Epoch 48/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.1364 - accuracy: 0.9630 - val_loss: 1.8824 - val_accuracy: 0.5667 - lr: 4.0000e-04
# Epoch 49/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1251 - accuracy: 0.9639 - val_loss: 1.8982 - val_accuracy: 0.5806 - lr: 4.0000e-04
# Epoch 50/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1269 - accuracy: 0.9648 - val_loss: 1.9468 - val_accuracy: 0.5917 - lr: 4.0000e-04
# Epoch 51/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0974 - accuracy: 0.9787 - val_loss: 1.8967 - val_accuracy: 0.5861 - lr: 4.0000e-04
# Epoch 52/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0939 - accuracy: 0.9741 - val_loss: 2.0714 - val_accuracy: 0.5694 - lr: 4.0000e-04
# Epoch 53/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0958 - accuracy: 0.9750 - val_loss: 2.1442 - val_accuracy: 0.5722 - lr: 4.0000e-04
# Epoch 54/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0983 - accuracy: 0.9713 - val_loss: 2.0620 - val_accuracy: 0.5833 - lr: 4.0000e-04
# Epoch 55/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0945 - accuracy: 0.9778 - val_loss: 2.0047 - val_accuracy: 0.5806 - lr: 1.6000e-04
# Epoch 56/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0769 - accuracy: 0.9824 - val_loss: 2.0372 - val_accuracy: 0.5750 - lr: 1.6000e-04
# Epoch 57/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0711 - accuracy: 0.9861 - val_loss: 2.0787 - val_accuracy: 0.5861 - lr: 1.6000e-04
# Epoch 58/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0703 - accuracy: 0.9843 - val_loss: 2.0796 - val_accuracy: 0.5750 - lr: 1.6000e-04
# Epoch 59/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0727 - accuracy: 0.9787 - val_loss: 2.2171 - val_accuracy: 0.5778 - lr: 1.6000e-04
# Epoch 60/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0590 - accuracy: 0.9898 - val_loss: 2.2362 - val_accuracy: 0.5833 - lr: 1.6000e-04
# Epoch 61/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0775 - accuracy: 0.9796 - val_loss: 2.1365 - val_accuracy: 0.5861 - lr: 1.6000e-04
# Epoch 62/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0679 - accuracy: 0.9843 - val_loss: 2.2208 - val_accuracy: 0.5972 - lr: 1.6000e-04
# Epoch 63/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0761 - accuracy: 0.9833 - val_loss: 2.1728 - val_accuracy: 0.5722 - lr: 6.4000e-05
# Epoch 64/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0639 - accuracy: 0.9861 - val_loss: 2.2327 - val_accuracy: 0.5694 - lr: 6.4000e-05
# Epoch 65/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0617 - accuracy: 0.9852 - val_loss: 2.2033 - val_accuracy: 0.5722 - lr: 2.5600e-05
# Epoch 66/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0708 - accuracy: 0.9815 - val_loss: 2.1546 - val_accuracy: 0.5722 - lr: 2.5600e-05
# Epoch 67/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0641 - accuracy: 0.9815 - val_loss: 2.1545 - val_accuracy: 0.5750 - lr: 1.0240e-05
# Epoch 68/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0534 - accuracy: 0.9880 - val_loss: 2.1590 - val_accuracy: 0.5778 - lr: 1.0240e-05
# Epoch 69/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0627 - accuracy: 0.9870 - val_loss: 2.1773 - val_accuracy: 0.5778 - lr: 1.0240e-05
# Epoch 70/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0609 - accuracy: 0.9843 - val_loss: 2.1861 - val_accuracy: 0.5778 - lr: 1.0240e-05
# Epoch 71/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0569 - accuracy: 0.9843 - val_loss: 2.1860 - val_accuracy: 0.5778 - lr: 4.0960e-06
# Epoch 72/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0621 - accuracy: 0.9880 - val_loss: 2.1838 - val_accuracy: 0.5778 - lr: 4.0960e-06
# Epoch 73/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0619 - accuracy: 0.9833 - val_loss: 2.1818 - val_accuracy: 0.5778 - lr: 1.6384e-06
# Epoch 74/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0672 - accuracy: 0.9843 - val_loss: 2.1815 - val_accuracy: 0.5778 - lr: 1.6384e-06
# Epoch 75/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0581 - accuracy: 0.9815 - val_loss: 2.1821 - val_accuracy: 0.5778 - lr: 6.5536e-07
# Epoch 76/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0500 - accuracy: 0.9917 - val_loss: 2.1823 - val_accuracy: 0.5778 - lr: 6.5536e-07
# Epoch 77/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0573 - accuracy: 0.9861 - val_loss: 2.1827 - val_accuracy: 0.5778 - lr: 6.5536e-07
# Epoch 78/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0578 - accuracy: 0.9833 - val_loss: 2.1831 - val_accuracy: 0.5778 - lr: 6.5536e-07
# Epoch 79/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0553 - accuracy: 0.9861 - val_loss: 2.1834 - val_accuracy: 0.5778 - lr: 2.6214e-07
# Epoch 80/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0655 - accuracy: 0.9852 - val_loss: 2.1835 - val_accuracy: 0.5778 - lr: 2.6214e-07
# Epoch 81/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0605 - accuracy: 0.9843 - val_loss: 2.1836 - val_accuracy: 0.5778 - lr: 1.0486e-07
# Epoch 82/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0601 - accuracy: 0.9880 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0486e-07
# Epoch 83/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0514 - accuracy: 0.9944 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 84/100
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0648 - accuracy: 0.9870 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 85/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0564 - accuracy: 0.9852 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 86/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0575 - accuracy: 0.9870 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 87/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0758 - accuracy: 0.9759 - val_loss: 2.1836 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 88/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0580 - accuracy: 0.9880 - val_loss: 2.1836 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 89/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0634 - accuracy: 0.9843 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 90/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0647 - accuracy: 0.9815 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 91/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0607 - accuracy: 0.9889 - val_loss: 2.1836 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 92/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0606 - accuracy: 0.9861 - val_loss: 2.1836 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 93/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0669 - accuracy: 0.9843 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 94/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0648 - accuracy: 0.9852 - val_loss: 2.1837 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 95/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0518 - accuracy: 0.9870 - val_loss: 2.1838 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 96/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0571 - accuracy: 0.9898 - val_loss: 2.1839 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 97/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0520 - accuracy: 0.9898 - val_loss: 2.1840 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 98/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0624 - accuracy: 0.9824 - val_loss: 2.1841 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 99/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0603 - accuracy: 0.9907 - val_loss: 2.1841 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 100/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0538 - accuracy: 0.9907 - val_loss: 2.1841 - val_accuracy: 0.5778 - lr: 1.0000e-07

# %% [markdown]
# ## Results

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1841 - accuracy: 0.5778
# Accuracy of our model on test data :  57.777780294418335 %

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1             fear          fear
# 2         surprise      surprise
# 3            angry         angry
# 4             calm           sad
# 5          neutral          calm
# 6              sad          calm
# 7              sad          fear
# 8             calm       disgust
# 9          disgust       disgust

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.73      0.71      0.72        45
#         calm       0.69      0.70      0.70        54
#      disgust       0.53      0.46      0.49        46
#         fear       0.63      0.36      0.46        47
#        happy       0.48      0.60      0.53        42
#      neutral       0.40      0.50      0.44        28
#          sad       0.47      0.62      0.54        45
#     surprise       0.69      0.62      0.65        53
#
#     accuracy                           0.58       360
#    macro avg       0.58      0.57      0.57       360
# weighted avg       0.59      0.58      0.58       360
