# %% [markdown]
# La idea es que sea una notebook simple, usando RAVDESS, MFCC y CNN

# %% [markdown]
# ## Imports

# %%
import os
import sys

# Set parent directory
os.chdir(os.path.dirname(os.getcwd()))

import pandas as pd
import numpy as np

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
#import librosa.display # Aparentemente esto bugea todo segun un git issue 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
# from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

from joblib import dump, load

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Data load

# %%
base_url = "C:/Users/Emanuel/Documents/Github/SER/datasets"

# Paths for data.
Ravdess = f"{base_url}/RAVDESS/audio_speech_actors_01-24"

ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + f'/{dir}')
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + f'/{dir}/{file}')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 1  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 2  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 3  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 4     calm  C:/Users/Emanuel/Documents/Github/SER/datasets...

# %% [markdown]
# ## Feature Extraction

# %%
X, Y = [], []

for path, emotion in zip(Ravdess_df.Path, Ravdess_df.Emotions):
    
    data, sample_rate = librosa.load(path)
    
    X.append(librosa.feature.mfcc(y = data, sr = sample_rate).T.mean(axis = 0))
    Y.append(emotion)
    
df_features = pd.DataFrame(X)

df_features['labels'] = Y

# %% [markdown]
# ## Data preparation

# %%
X = df_features.iloc[: ,:-1].values
Y = df_features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20), (1080, 8), (360, 20), (360, 8))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20), (1080, 8), (360, 20), (360, 8))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 20, 1), (1080, 8), (360, 20, 1), (360, 8))

# %% [markdown]
# ## Model Training

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 256)           1536
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           327936
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            163968
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 128)            0
#  g1D)
#
#  dropout (Dropout)           (None, 3, 128)            0
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             41024
#
#  max_pooling1d_3 (MaxPoolin  (None, 2, 64)             0
#  g1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 538856 (2.06 MB)
# Trainable params: 538856 (2.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 22ms/step - loss: 2.0829 - accuracy: 0.1454 - val_loss: 2.0547 - val_accuracy: 0.1472 - lr: 0.0010
# Epoch 2/100
# 17/17 [==============================] - 0s 13ms/step - loss: 2.0451 - accuracy: 0.1574 - val_loss: 2.0104 - val_accuracy: 0.1861 - lr: 0.0010
# Epoch 3/100
# 17/17 [==============================] - 0s 14ms/step - loss: 2.0206 - accuracy: 0.1815 - val_loss: 1.9810 - val_accuracy: 0.2278 - lr: 0.0010
# Epoch 4/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.9839 - accuracy: 0.2167 - val_loss: 1.9521 - val_accuracy: 0.2194 - lr: 0.0010
# Epoch 5/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.9660 - accuracy: 0.2157 - val_loss: 1.9103 - val_accuracy: 0.2972 - lr: 0.0010
# Epoch 6/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.9350 - accuracy: 0.2407 - val_loss: 1.8911 - val_accuracy: 0.2694 - lr: 0.0010
# Epoch 7/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.8758 - accuracy: 0.2565 - val_loss: 1.7852 - val_accuracy: 0.3083 - lr: 0.0010
# Epoch 8/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.8381 - accuracy: 0.2833 - val_loss: 1.7606 - val_accuracy: 0.2972 - lr: 0.0010
# Epoch 9/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.7961 - accuracy: 0.3074 - val_loss: 1.7384 - val_accuracy: 0.3389 - lr: 0.0010
# Epoch 10/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.7181 - accuracy: 0.3176 - val_loss: 1.6309 - val_accuracy: 0.3833 - lr: 0.0010
# Epoch 11/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.7028 - accuracy: 0.3278 - val_loss: 1.6653 - val_accuracy: 0.3639 - lr: 0.0010
# Epoch 12/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.6518 - accuracy: 0.3491 - val_loss: 1.6583 - val_accuracy: 0.3389 - lr: 0.0010
# Epoch 13/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.6295 - accuracy: 0.3583 - val_loss: 1.5467 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 14/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.5935 - accuracy: 0.3750 - val_loss: 1.5671 - val_accuracy: 0.3972 - lr: 0.0010
# Epoch 15/100
# 17/17 [==============================] - 0s 13ms/step - loss: 1.5931 - accuracy: 0.3898 - val_loss: 1.5638 - val_accuracy: 0.4056 - lr: 0.0010
# Epoch 16/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.5313 - accuracy: 0.4111 - val_loss: 1.5223 - val_accuracy: 0.3917 - lr: 0.0010
# Epoch 17/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.4489 - accuracy: 0.4509 - val_loss: 1.4567 - val_accuracy: 0.4389 - lr: 0.0010
# Epoch 18/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.4074 - accuracy: 0.4630 - val_loss: 1.4672 - val_accuracy: 0.4361 - lr: 0.0010
# Epoch 19/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.3518 - accuracy: 0.4861 - val_loss: 1.4355 - val_accuracy: 0.4444 - lr: 0.0010
# Epoch 20/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.3619 - accuracy: 0.4796 - val_loss: 1.5298 - val_accuracy: 0.3778 - lr: 0.0010
# Epoch 21/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.3241 - accuracy: 0.4843 - val_loss: 1.3819 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 22/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.2422 - accuracy: 0.5315 - val_loss: 1.4340 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 23/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.2122 - accuracy: 0.5509 - val_loss: 1.3719 - val_accuracy: 0.4694 - lr: 0.0010
# Epoch 24/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.1801 - accuracy: 0.5491 - val_loss: 1.3939 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 25/100
# 17/17 [==============================] - 0s 16ms/step - loss: 1.1073 - accuracy: 0.5769 - val_loss: 1.3996 - val_accuracy: 0.4861 - lr: 0.0010
# Epoch 26/100
# 17/17 [==============================] - 0s 15ms/step - loss: 1.1084 - accuracy: 0.5861 - val_loss: 1.3320 - val_accuracy: 0.5222 - lr: 0.0010
# Epoch 27/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9961 - accuracy: 0.6241 - val_loss: 1.2999 - val_accuracy: 0.5222 - lr: 0.0010
# Epoch 28/100
# 17/17 [==============================] - 0s 14ms/step - loss: 1.0398 - accuracy: 0.5991 - val_loss: 1.3741 - val_accuracy: 0.4972 - lr: 0.0010
# Epoch 29/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9687 - accuracy: 0.6343 - val_loss: 1.3359 - val_accuracy: 0.4806 - lr: 0.0010
# Epoch 30/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.8862 - accuracy: 0.6509 - val_loss: 1.4239 - val_accuracy: 0.5250 - lr: 0.0010
# Epoch 31/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.9122 - accuracy: 0.6500 - val_loss: 1.3323 - val_accuracy: 0.5056 - lr: 0.0010
# Epoch 32/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.9256 - accuracy: 0.6565 - val_loss: 1.3997 - val_accuracy: 0.4722 - lr: 0.0010
# Epoch 33/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.7573 - accuracy: 0.7398 - val_loss: 1.3531 - val_accuracy: 0.5194 - lr: 4.0000e-04
# Epoch 34/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6978 - accuracy: 0.7407 - val_loss: 1.3240 - val_accuracy: 0.5222 - lr: 4.0000e-04
# Epoch 35/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6351 - accuracy: 0.7676 - val_loss: 1.3506 - val_accuracy: 0.5361 - lr: 4.0000e-04
# Epoch 36/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6115 - accuracy: 0.7713 - val_loss: 1.4034 - val_accuracy: 0.5167 - lr: 4.0000e-04
# Epoch 37/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5796 - accuracy: 0.7806 - val_loss: 1.3256 - val_accuracy: 0.5333 - lr: 4.0000e-04
# Epoch 38/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6064 - accuracy: 0.7676 - val_loss: 1.3845 - val_accuracy: 0.5583 - lr: 4.0000e-04
# Epoch 39/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5718 - accuracy: 0.7750 - val_loss: 1.3707 - val_accuracy: 0.5639 - lr: 4.0000e-04
# Epoch 40/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.5747 - accuracy: 0.7861 - val_loss: 1.3838 - val_accuracy: 0.5500 - lr: 4.0000e-04
# Epoch 41/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5399 - accuracy: 0.8148 - val_loss: 1.4838 - val_accuracy: 0.5389 - lr: 4.0000e-04
# Epoch 42/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5332 - accuracy: 0.8037 - val_loss: 1.3640 - val_accuracy: 0.5500 - lr: 4.0000e-04
# Epoch 43/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4943 - accuracy: 0.8204 - val_loss: 1.4206 - val_accuracy: 0.5500 - lr: 4.0000e-04
# Epoch 44/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4564 - accuracy: 0.8361 - val_loss: 1.3949 - val_accuracy: 0.5667 - lr: 4.0000e-04
# Epoch 45/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4877 - accuracy: 0.8148 - val_loss: 1.4371 - val_accuracy: 0.5528 - lr: 4.0000e-04
# Epoch 46/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4361 - accuracy: 0.8389 - val_loss: 1.4426 - val_accuracy: 0.5500 - lr: 4.0000e-04
# Epoch 47/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4258 - accuracy: 0.8583 - val_loss: 1.3891 - val_accuracy: 0.5722 - lr: 4.0000e-04
# Epoch 48/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4051 - accuracy: 0.8472 - val_loss: 1.4133 - val_accuracy: 0.5750 - lr: 4.0000e-04
# Epoch 49/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3904 - accuracy: 0.8556 - val_loss: 1.4143 - val_accuracy: 0.5667 - lr: 4.0000e-04
# Epoch 50/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3852 - accuracy: 0.8639 - val_loss: 1.4690 - val_accuracy: 0.5667 - lr: 4.0000e-04
# Epoch 51/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3638 - accuracy: 0.8741 - val_loss: 1.4999 - val_accuracy: 0.5694 - lr: 4.0000e-04
# Epoch 52/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3664 - accuracy: 0.8676 - val_loss: 1.5217 - val_accuracy: 0.5694 - lr: 4.0000e-04
# Epoch 53/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3704 - accuracy: 0.8806 - val_loss: 1.4489 - val_accuracy: 0.5861 - lr: 4.0000e-04
# Epoch 54/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3290 - accuracy: 0.8907 - val_loss: 1.5179 - val_accuracy: 0.5639 - lr: 1.6000e-04
# Epoch 55/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2932 - accuracy: 0.8991 - val_loss: 1.5942 - val_accuracy: 0.5722 - lr: 1.6000e-04
# Epoch 56/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2859 - accuracy: 0.9065 - val_loss: 1.5935 - val_accuracy: 0.5639 - lr: 1.6000e-04
# Epoch 57/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2745 - accuracy: 0.9083 - val_loss: 1.5375 - val_accuracy: 0.5750 - lr: 1.6000e-04
# Epoch 58/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2872 - accuracy: 0.9009 - val_loss: 1.5647 - val_accuracy: 0.5556 - lr: 1.6000e-04
# Epoch 59/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2756 - accuracy: 0.9102 - val_loss: 1.5884 - val_accuracy: 0.5639 - lr: 1.6000e-04
# Epoch 60/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2658 - accuracy: 0.9176 - val_loss: 1.5695 - val_accuracy: 0.5639 - lr: 6.4000e-05
# Epoch 61/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2461 - accuracy: 0.9213 - val_loss: 1.6104 - val_accuracy: 0.5639 - lr: 6.4000e-05
# Epoch 62/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2451 - accuracy: 0.9241 - val_loss: 1.5920 - val_accuracy: 0.5778 - lr: 6.4000e-05
# Epoch 63/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2384 - accuracy: 0.9231 - val_loss: 1.5923 - val_accuracy: 0.5722 - lr: 6.4000e-05
# Epoch 64/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2323 - accuracy: 0.9389 - val_loss: 1.6314 - val_accuracy: 0.5639 - lr: 6.4000e-05
# Epoch 65/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2303 - accuracy: 0.9333 - val_loss: 1.6635 - val_accuracy: 0.5722 - lr: 6.4000e-05
# Epoch 66/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2339 - accuracy: 0.9278 - val_loss: 1.6319 - val_accuracy: 0.5750 - lr: 6.4000e-05
# Epoch 67/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2320 - accuracy: 0.9241 - val_loss: 1.6655 - val_accuracy: 0.5556 - lr: 6.4000e-05
# Epoch 68/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2391 - accuracy: 0.9130 - val_loss: 1.6436 - val_accuracy: 0.5667 - lr: 2.5600e-05
# Epoch 69/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2430 - accuracy: 0.9176 - val_loss: 1.6472 - val_accuracy: 0.5750 - lr: 2.5600e-05
# Epoch 70/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2385 - accuracy: 0.9222 - val_loss: 1.6581 - val_accuracy: 0.5694 - lr: 1.0240e-05
# Epoch 71/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2349 - accuracy: 0.9352 - val_loss: 1.6686 - val_accuracy: 0.5667 - lr: 1.0240e-05
# Epoch 72/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2283 - accuracy: 0.9241 - val_loss: 1.6644 - val_accuracy: 0.5639 - lr: 4.0960e-06
# Epoch 73/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2366 - accuracy: 0.9269 - val_loss: 1.6581 - val_accuracy: 0.5694 - lr: 4.0960e-06
# Epoch 74/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2196 - accuracy: 0.9315 - val_loss: 1.6582 - val_accuracy: 0.5694 - lr: 4.0960e-06
# Epoch 75/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2318 - accuracy: 0.9259 - val_loss: 1.6620 - val_accuracy: 0.5667 - lr: 4.0960e-06
# Epoch 76/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2200 - accuracy: 0.9306 - val_loss: 1.6665 - val_accuracy: 0.5639 - lr: 4.0960e-06
# Epoch 77/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2443 - accuracy: 0.9167 - val_loss: 1.6657 - val_accuracy: 0.5639 - lr: 1.6384e-06
# Epoch 78/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2367 - accuracy: 0.9204 - val_loss: 1.6633 - val_accuracy: 0.5639 - lr: 1.6384e-06
# Epoch 79/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2292 - accuracy: 0.9204 - val_loss: 1.6622 - val_accuracy: 0.5667 - lr: 6.5536e-07
# Epoch 80/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2220 - accuracy: 0.9306 - val_loss: 1.6619 - val_accuracy: 0.5667 - lr: 6.5536e-07
# Epoch 81/100
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2156 - accuracy: 0.9269 - val_loss: 1.6615 - val_accuracy: 0.5694 - lr: 2.6214e-07
# Epoch 82/100
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2491 - accuracy: 0.9176 - val_loss: 1.6614 - val_accuracy: 0.5694 - lr: 2.6214e-07
# Epoch 83/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2377 - accuracy: 0.9213 - val_loss: 1.6612 - val_accuracy: 0.5694 - lr: 2.6214e-07
# Epoch 84/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2265 - accuracy: 0.9343 - val_loss: 1.6611 - val_accuracy: 0.5694 - lr: 1.0486e-07
# Epoch 85/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2066 - accuracy: 0.9407 - val_loss: 1.6612 - val_accuracy: 0.5694 - lr: 1.0486e-07
# Epoch 86/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2259 - accuracy: 0.9269 - val_loss: 1.6611 - val_accuracy: 0.5694 - lr: 1.0486e-07
# Epoch 87/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2307 - accuracy: 0.9241 - val_loss: 1.6610 - val_accuracy: 0.5694 - lr: 1.0486e-07
# Epoch 88/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2151 - accuracy: 0.9343 - val_loss: 1.6609 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 89/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2392 - accuracy: 0.9194 - val_loss: 1.6608 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 90/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2283 - accuracy: 0.9213 - val_loss: 1.6607 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 91/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2095 - accuracy: 0.9380 - val_loss: 1.6607 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 92/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2444 - accuracy: 0.9120 - val_loss: 1.6606 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 93/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2224 - accuracy: 0.9278 - val_loss: 1.6606 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 94/100
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2443 - accuracy: 0.9139 - val_loss: 1.6605 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 95/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2312 - accuracy: 0.9204 - val_loss: 1.6605 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 96/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2402 - accuracy: 0.9204 - val_loss: 1.6604 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 97/100
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2359 - accuracy: 0.9231 - val_loss: 1.6603 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 98/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2297 - accuracy: 0.9278 - val_loss: 1.6602 - val_accuracy: 0.5694 - lr: 1.0000e-07
# Epoch 99/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2147 - accuracy: 0.9306 - val_loss: 1.6602 - val_accuracy: 0.5722 - lr: 1.0000e-07
# Epoch 100/100
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2336 - accuracy: 0.9287 - val_loss: 1.6603 - val_accuracy: 0.5694 - lr: 1.0000e-07

# %% [markdown]
# ## Results

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6603 - accuracy: 0.5694
# Accuracy of our model on test data :  56.94444179534912 %

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1             fear          fear
# 2         surprise      surprise
# 3            angry         angry
# 4             calm           sad
# 5             calm          calm
# 6              sad          calm
# 7              sad          fear
# 8          disgust       disgust
# 9          disgust       disgust

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.74      0.76      0.75        45
#         calm       0.73      0.70      0.72        54
#      disgust       0.55      0.48      0.51        46
#         fear       0.66      0.45      0.53        47
#        happy       0.50      0.60      0.54        42
#      neutral       0.42      0.46      0.44        28
#          sad       0.38      0.51      0.43        45
#     surprise       0.60      0.55      0.57        53
#
#     accuracy                           0.57       360
#    macro avg       0.57      0.56      0.56       360
# weighted avg       0.58      0.57      0.57       360
