# %% [markdown]
# - Agrega offset de 0.5 y duration reducida a 2.5 respecto a v1 (Resultado: Mejora de accuracy de 5%)
# - Agregar 5 bines (Resultado: Caída de accuracy de 10%)

# %% [markdown]
# ## Imports

# %%
import os
import sys

# Set parent directory
os.chdir(os.path.dirname(os.getcwd()))

import pandas as pd
import numpy as np

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
#import librosa.display # Aparentemente esto bugea todo segun un git issue 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import keras
from python_speech_features import mfcc
import scipy.io.wavfile as wav
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
# from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

from joblib import dump, load

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Data load

# %%
base_url = "C:/Users/Emanuel/Documents/Github/SER/datasets"

# Paths for data.
Ravdess = f"{base_url}/RAVDESS/audio_speech_actors_01-24"

ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + f'/{dir}')
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + f'/{dir}/{file}')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 1  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 2  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 3  neutral  C:/Users/Emanuel/Documents/Github/SER/datasets...
# 4     calm  C:/Users/Emanuel/Documents/Github/SER/datasets...

# %% [markdown]
# ## Feature Extraction

# %%
X, Y = [], []

for path, emotion in zip(Ravdess_df.Path, Ravdess_df.Emotions):
    
    data, sample_rate = librosa.load(path, duration = 2.5, offset = 0.5)
    
    X.append(bin_features(data, sample_rate, 5))
    Y.append(emotion)
    
df_features = pd.DataFrame(X)

df_features['labels'] = Y

# %% [markdown]
# ## Data preparation

# %%
X = df_features.iloc[: ,:-1].values
Y = df_features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 100), (1080, 8), (360, 100), (360, 8))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 100), (1080, 8), (360, 100), (360, 8))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 100, 1), (1080, 8), (360, 100, 1), (360, 8))

# %% [markdown]
# ## Model Training

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 100, 256)          1536
#
#  max_pooling1d (MaxPooling1  (None, 50, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 50, 256)           327936
#
#  max_pooling1d_1 (MaxPoolin  (None, 25, 256)           0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 25, 128)           163968
#
#  max_pooling1d_2 (MaxPoolin  (None, 13, 128)           0
#  g1D)
#
#  dropout (Dropout)           (None, 13, 128)           0
#
#  conv1d_3 (Conv1D)           (None, 13, 64)            41024
#
#  max_pooling1d_3 (MaxPoolin  (None, 7, 64)             0
#  g1D)
#
#  flatten (Flatten)           (None, 448)               0
#
#  dense (Dense)               (None, 32)                14368
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 549096 (2.09 MB)
# Trainable params: 549096 (2.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose
# Epoch 90/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.3853 - accuracy: 0.8593 - val_loss: 1.9008 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 91/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.3775 - accuracy: 0.8528 - val_loss: 1.9008 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 92/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.3981 - accuracy: 0.8639 - val_loss: 1.9008 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 93/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.4121 - accuracy: 0.8398 - val_loss: 1.9007 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 94/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4005 - accuracy: 0.8593 - val_loss: 1.9007 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 95/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.3731 - accuracy: 0.8713 - val_loss: 1.9007 - val_accuracy: 0.4972 - lr: 1.0000e-07
# Epoch 96/100
# 17/17 [==============================] - 1s 59ms/step - loss: 0.4009 - accuracy: 0.8481 - val_loss: 1.9007 - val_accuracy: 0.4972 - lr: 1.0000e-07
# Epoch 97/100
# 17/17 [==============================] - 1s 65ms/step - loss: 0.3910 - accuracy: 0.8565 - val_loss: 1.9007 - val_accuracy: 0.4972 - lr: 1.0000e-07
# Epoch 98/100
# 17/17 [==============================] - 1s 70ms/step - loss: 0.3823 - accuracy: 0.8722 - val_loss: 1.9007 - val_accuracy: 0.4972 - lr: 1.0000e-07
# Epoch 99/100
# 17/17 [==============================] - 1s 69ms/step - loss: 0.4101 - accuracy: 0.8463 - val_loss: 1.9008 - val_accuracy: 0.4972 - lr: 1.0000e-07
# Epoch 100/100
# 17/17 [==============================] - 1s 63ms/step - loss: 0.3969 - accuracy: 0.8556 - val_loss: 1.9007 - val_accuracy: 0.4972 - lr: 1.0000e-07

# %% [markdown]
# ## Results

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9007 - accuracy: 0.4972
# Accuracy of our model on test data :  49.72222149372101 %

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 12/12 [==============================] - 0s 7ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1            angry          fear
# 2         surprise      surprise
# 3            angry         angry
# 4              sad           sad
# 5             calm          calm
# 6              sad          calm
# 7             fear          fear
# 8          disgust       disgust
# 9         surprise       disgust

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.56      0.51      0.53        45
#         calm       0.69      0.67      0.68        54
#      disgust       0.48      0.43      0.45        46
#         fear       0.40      0.40      0.40        47
#        happy       0.48      0.48      0.48        42
#      neutral       0.65      0.39      0.49        28
#          sad       0.27      0.44      0.34        45
#     surprise       0.67      0.57      0.61        53
#
#     accuracy                           0.50       360
#    macro avg       0.52      0.49      0.50       360
# weighted avg       0.52      0.50      0.51       360
